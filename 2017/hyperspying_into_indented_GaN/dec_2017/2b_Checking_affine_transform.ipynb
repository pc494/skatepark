# %%
import hyperspy.api as hs
from matplotlib import pyplot as plt
import numpy as np
import pycrystem as pc

plt.rcParams['image.cmap'] = 'viridis'
# %matplotlib inline

# %%
signal_zero = hs.load("/home/pc494/Documents/data/GaN_intro/GaN_indent.blo")
signal_zero
# Out:
# <Signal2D, title: , dimensions: (500, 500|144, 144)>

# %%
single_image = signal_zero.inav[200,200]
print(single_image)
single_image.plot()
# Out:
# <Signal2D, title: , dimensions: (|144, 144)>

# %%
dp = pc.diffraction_signal.ElectronDiffraction(single_image);
dp.apply_affine_transformation(np.array([[0.99,0,0],[0,0.69,0],[0,0,1]]));
dp.plot()
dp.data.shape
# Out:
# A Jupyter Widget
# (144, 144)

# %%
signal_zero.inav[200,200]= dp.data;

# %%
single_image = signal_zero.inav[200,200]
single_image.plot()
